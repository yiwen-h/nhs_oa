# %%
import pickle

# %%
with open('../errors.pkl', 'rb') as f:
    errors = pickle.load(f)

# %%
errors[5]
# Out:
# ['10.1136/heartjnl-2017-312755']

# %%
import pandas as pd

# %%
df = pd.read_csv("../csv/2019_crossref_pubmed_upw.csv")
df.head()
# Out:
#    Unnamed: 0      pmid                             doi  \
# 0           0  30872305   10.7861/clinmedicine.19-2-169
# 1           1  30609105               10.1111/ced.13891
# 2           3  30525757         10.21037/cco.2018.11.03
# 3           4  30500591      10.1016/j.wneu.2018.11.176
# 4           5  30657163  10.1002/14651858.CD006583.pub5
#
#                                         affiliations  \
# 0             ['Walton Centre NHS Foundation Trust']
# 1  ['Sheffield Teaching Hospitals NHS Foundation ...
# 2  ['University Hospital Birmingham', 'University...
# 3                             ['Derriford Hospital']
# 4              ['Pennine Acute Hospitals NHS Trust']
#
#                                             abstract date_published  \
# 0  Neuromyelitis optica spectrum disorder (NMOSD)...      [2019, 3]
# 1  Erythromelalgia is a condition characterized b...   [2019, 1, 4]
# 2  Mycosis fungoides (MF) represents the majority...      [2019, 3]
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                    0
# pmid                          0
# doi                           0
# affiliations                  0
# abstract                   2784
# date_published              311
# author_list                 154
# journal title               311
# article title               311
# num_citations_crossref      311
# num_references_crossref     311
# date_published_upw          288
# is_oa                       288
# oa_status                   288
# oa_locations                288
# genre                       288
# dtype: int64
